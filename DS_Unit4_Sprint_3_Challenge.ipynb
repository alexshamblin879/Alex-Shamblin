# %% [markdown]
# <a href="https://colab.research.google.com/github/alexshamblin879/Alex-Shamblin/blob/main/DS_Unit4_Sprint_3_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

class StoryBot:
    def __init__(self, model_name: str = "EleutherAI/gpt-neo-1.3B"):
        """
        Initializes the StoryBot with a specified pre-trained model.

        :param model_name: Name of the pre-trained model from Hugging Face
        """
        # Load the tokenizer and model
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModelForCausalLM.from_pretrained(model_name)

        # Check if a GPU is available and use it if possible
        if torch.cuda.is_available():
            self.model = self.model.to('cuda')

    def __call__(self, user_prompt: str, max_length: int = 1000) -> str:
        """
        Generates a story based on the user prompt.

        :param user_prompt: The prompt provided by the user to generate a story.
        :param max_length: Maximum length of the generated story.
        :return: The generated story as a string.
        """
        # Encode the user prompt
        input_ids = self.tokenizer.encode(user_prompt, return_tensors='pt')

        # Move input_ids to GPU if available
        if torch.cuda.is_available():
            input_ids = input_ids.to('cuda')

        # Generate text
        output = self.model.generate(
            input_ids,
            max_length=max_length,
            num_return_sequences=1,
            no_repeat_ngram_size=2,
            early_stopping=True,
            temperature=0.7,  # Controls randomness
            top_k=50,         # Limits the number of highest probability vocabulary tokens
            top_p=0.95        # Nucleus sampling
        )

        # Decode the generated text
        story = self.tokenizer.decode(output[0], skip_special_tokens=True)
        return story

# Example usage
if __name__ == "__main__":
    story_bot = StoryBot()

    # Example user prompts
    prompt = [
        "Once upon a time in a land far away, there lived a brave knight..."
    ]

    # Generate and print stories
    for prompt in prompt:
        print(f"Prompt: {prompt}")
        story = story_bot(prompt)
        print(f"Generated Story:\n{story}\n{'-'*80}\n")


        # Save the generated story to a file
        with open('story.txt', 'w') as f:
          f.write(story)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/5.31G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:628: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:633: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:676: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Prompt: Once upon a time in a land far away, there lived a brave knight.
# Generated Story:
# Once upon a time in a land far away, there lived a brave knight. He was a man of great strength and courage. His name was Sir Lancelot.
#
# Sir Lancelot was the son of a noble knight, and he was also the grandson of the king of England. Sir Lelot had a beautiful wife, who was named Guinevere. She was beautiful and kind, but she was not a lady. Her name, however, was Guenever. The king was very fond of Sir Guenevere, so he gave her a great many lands and titles. One day, Sir Gwen was riding on a horse, when she saw a knight riding towards her. When she asked him what he wanted, he told her that he had come to ask her to marry him. Guwenvere was so surprised that she could not speak. Then Sir Gawain came up to her and asked her if she would marry Sir Sir Galahad. This was her reply:
# "I will not marry you, for I am a woman of noble birth, a princess of royal blood, the daughter of King Arthur, son to King Uther Pendragon, King of Britain. I will never marry a commoner."
# Gwen then rode away and left Sir Uryen and Sir Gareth behind. They were very angry with her, because she had not told them that Sir Arthur was their father. So they rode after her until they caught up with Sir Mordred. Mordrred was an evil man, as he always had been. But he did not know that Guennewere was his daughter. As soon as Mordrured saw that his enemy was in the same predicament as himself, his heart was filled with joy. "I have found my daughter," he said. And he rode off to find her himself. After a while, Mordrus rode up and said to Sir Ector, "Sir, I have come from the court of Arthur to tell you that your daughter is here." Ecter was greatly surprised, thinking that Mordre was mad. However, Ectors daughter was there, riding in her father's arms. Eector was delighted to see his son again, especially after he saw Mordres daughter, whom he loved so much. It was then that Eecter told Mordrer that Arthur had sent him to get his wife. Arthur did this because he knew that the two of them would be enemies. Therefore, Arthur sent Mordere to the castle of Mordur, where he found his own daughter Guennevere and her husband Sir Percivale. Percevale was Arthur's son by his first wife and was now a very old man. In fact, Percy was almost blind. At first, Guenna was afraid of Percin, since he looked so old. Nevertheless, she did her best to make him happy. For a long time, they were happy together. Finally, one day Percu was taken ill and died. That was when Guennes daughter and Perces son were married. Now, it was time for Sir Peccei to go to Arthur. Pecters son was still very young, only a few years older than Guenes daughter by Percus death. Thus, Pector and Guens daughter were now married, with Percs son as their son-in-law. All of this was done in secret, of course. No one knew about it. There was no one to stop them. Everyone was happy, except Sir Bors, whose daughter had married Sir Tristram. Bores daughter loved Sir Tressram, although she knew he would never be happy with his father- in- law. Trissram was always very jealous of his sister, even though she loved him very much, too. Tresram had no children, which made him a widower. Because of that, Trisram did everything he could to keep his brother from marrying his mother. Eventually, Bres and Trish were both married to other people. Their children were all dead. Even so, their mother was left with a son, named Sir Kay. Kay was born in an old castle in Wales, near the border of Wales and England, in which there was much fighting. A Welsh knight named Kay, called Sir Gwydion, had many sons and daughters. Many of these children had died in infancy. Some of their mothers had also died, leaving their children orphans. These children lived in great poverty. Most of all, these orphans were in need of someone to take care of. Someone who would take them to Wales to live with their grandfather, Kay's father, to be raised as his sons. Unfortunately, this Kay had never been to his grandfather's castle. Instead, all he remembered was that there were many castles in England and Wales. Since he never had any brothers or sisters, or any other relatives, no-one would ever
# --------------------------------------------------------------------------------
